# %% [markdown]
# ### Matplotlib
#
# Библиотека Matplotlib - это библиотека двумерной графики для языка программирования Python, с помощью которой можно создавать высококачественные рисунки различных форматов

# %% [markdown]
# Официальная документация по matplotlib - https://matplotlib.org/index.html.

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib

#Корректное отображение графиков прямо в jupyter'e
# %matplotlib inline
#Все функции matplotlib API, в частности plot и close, находятся в модуле matplotlib.pyplot
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ах2 = fig.add_subplot(222) 
ax3 = fig.add_subplot(223)  
ax4 = fig.add_subplot(224)  

plt.show()
plt.close()

# %% [markdown]
# -----------

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221) #обращаемся к графику, исходя из того, что сетка состоит из 2 строк и 2 столбцов
ах2 = fig.add_subplot(222) 
ax3 = fig.add_subplot(212) #число строк = 2, число столбцов = 1

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ах2 = fig.add_subplot(122) 
ax3 = fig.add_subplot(223)

# %%
from numpy.random import randn
import numpy as np

# %%
fig = plt.figure(figsize= (14,5))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(122) 
ax3 = fig.add_subplot(223)

# plt.plot(randn(100).cumsum(), 'k--')

# Метод fig.add_subplot возвращает объект AxesSubplot, что позволяет рисовать в любом подrрафике, вызывая методы этого объекта:
f = ax1.hist(randn(100), bins=20, color='y', alpha=0.5)
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30)) 
ax3.plot(randn(100).cumsum(), 'k--')

# %%
f #здесь находятся параметры, по которым нарисована наша гистограмма, в дальнейшем их можно использовать также и для анализа данных
# Out:
# (array([ 2.,  2.,  1.,  5.,  6.,  7., 12.,  9., 13.,  4.,  6.,  4.,  9.,
#          7.,  7.,  3.,  2.,  0.,  0.,  1.]),
#  array([-2.42193678, -2.15874144, -1.8955461 , -1.63235077, -1.36915543,
#         -1.10596009, -0.84276475, -0.57956941, -0.31637407, -0.05317873,
#          0.2100166 ,  0.47321194,  0.73640728,  0.99960262,  1.26279796,
#          1.5259933 ,  1.78918863,  2.05238397,  2.31557931,  2.57877465,
#          2.84196999]),
#  <BarContainer object of 20 artists>)

# %%
#Отдельно данный метод тоже будет работать, так как при необходимости он автоматически создаст рисунок и подграфик
plt.plot(randn(100).cumsum())

# %%
fig, axes = plt.subplots(2, 3) #указали сетку, в которой содержится количество строк и столбцов
fig.set_figheight(5) #масштаб
fig.set_figwidth(15)

axes[0,1].scatter(np.arange(30), np.arange(30) + 3 * randn(30))  #обращаемся к сетке по индексам
axes[1,1].bar(np.arange(10),  randn(10)) 
plt.show()

# %%
axes #тут хранятся наши 6 подграфиков
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
#Можно задавать каждый из подграфиков с помощью цикла
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
fig.set_figheight(5)
fig.set_figwidth(15)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color= 'r', alpha=0.5) 
#Достаточно популярный способ задания пустого пространства вокруг графиков         
plt.subplots_adjust(wspace=0.0, hspace=0.1)

# %%
#Обратить внимание на общую ось sharex = False - делает оси раздельными
fig, axes = plt.subplots(2, 2, sharex=False, sharey=False)
fig.set_figheight(5)
fig.set_figwidth(15)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color= 'r', alpha=0.5) 
#Достаточно популярный способ задания пустого пространства вокруг графиков         
plt.subplots_adjust(wspace=0.2, hspace=0.2)

# %%
#Сохранение рисунка
plt.savefig('figpath.png', dpi=400, bbox_inches= 'tight')

# %% [markdown]
# ### Конфигурирование matplotlib

# %%
#Задает глобально размер рисунка
plt.rc('figure', figsize=(10, 10))
font_options = {'family' : 'monospace'} 
plt.rc('font', **font_options)
